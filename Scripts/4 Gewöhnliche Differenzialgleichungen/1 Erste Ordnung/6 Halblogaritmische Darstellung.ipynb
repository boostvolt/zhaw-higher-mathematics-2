# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming t, runge_kutta_sol, euler_sol are numpy arrays representing time and the solutions of the two methods
t = np.array([0.0, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0, 1.2000000000000002, 1.4000000000000001, 1.6, 1.8, 2.0, 2.2, 2.4000000000000004, 2.6, 2.8000000000000003, 3.0, 3.2, 3.4000000000000004, 3.6, 3.8000000000000003, 4.0, 4.2, 4.4, 4.6000000000000005, 4.800000000000001, 5.0, 5.2, 5.4, 5.6000000000000005, 5.800000000000001, 6.0])  # time array
runge_kutta_sol = np.array([0.0, 0.039736072419561896, 0.15373579378111124, 0.3256280720693189, 0.5299347201908297, 0.73609356545354, 0.9132842219979282, 1.035294643093598, 1.0846601319756188, 1.0554213527002112, 0.9540659120365348, 0.7985048576108937, 0.6152456810410765, 0.43520814701139526, 0.2888435371875747, 0.20132787335720348, 0.1885880044948261, 0.2547879515566224, 0.3916723612289586, 0.5798707231922228, 0.7919564440225324, 0.9967778175836748, 1.1643771272795485, 1.2707212624558308, 1.3014969890185495, 1.2543716848776807, 1.1393626201945128, 0.9772564816056639, 0.7963286632096582, 0.6278802765537432, 0.4358745845157098]) # solution from Runge-Kutta
euler_sol = np.array([0.0, 0.07788366846173012, 0.2229125600108693, 0.41377862840453195, 0.6219689215809237, 0.8162677853776785, 0.9676857771954622, 1.0540371227705525, 1.0634430365404475, 0.996207808612286, 0.864771465722946, 0.6917464802595017, 0.5063484880975236, 0.33978452671544346, 0.22032688967528813, 0.16885032782900872, 0.19553717535568763, 0.2982705890905232, 0.4629695736421643, 0.6658128995213048, 0.8770008068364072, 1.0654606045907915, 1.2037532552609598, 1.2724063031862283, 1.2629890730053566, 1.1794446322875898, 1.037468231116211, 0.8620303497252368, 0.6834354108894782, 0.5325384001135263, 0.4358745845157098])  # solution from classical Euler

# Calculate the absolute difference
diff = np.abs(runge_kutta_sol - euler_sol)

# Create a semi-logarithmic plot
plt.semilogy(t, diff)
plt.xlabel('Time (t)')
plt.ylabel('Absolute Difference')
plt.title('Absolute Difference between Runge-Kutta and Classical Euler')
plt.grid(True)
plt.show()
