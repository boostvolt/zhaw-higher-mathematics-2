# %%
import numpy as np
import matplotlib.pyplot as plt

#Intervall
a = 0.
b = 1.

#Schrittweite und Anzahl Schritte
h = 0.1
n = int((b-a)/h)

#Anzahl Zeilen im Vektor
rows = 4

x = np.zeros(n+1)
z = np.zeros([rows,n+1])

x[0] = a

#Startvektor
z[:,0] =np.array([0.,2.,0.,0.])

#Umgewandelte höhere Ordnung in 1. Ordnung
def f(x,z): 
    return np.array(
        [
            z[1], 
            z[2], 
            z[3], 
            np.sin(x)+5-1.1*z[3]+0.1*z[2]+0.3*z[0]
        ])


#Hier das richtige auskommentieren!

#Euler
# for i in range(0,n):
#     x[i+1]=x[i]+h
#     z[:,i+1]=z[:,i]+h*f(x[i],z[:,i])
    
#     print(x[i+1])
#     print(z[:,i+1])

#Mittelpunkt
# for i in range(0,n):
#     xh2 = x[i] + h / 2
#     yh2 = z[:,i] + h / 2 * f(x[i], z[:,i])

#     x[i+1]=x[i]+h
#     z[:,i+1]=z[:,i]+h*f(xh2, yh2)

#Modifiziert

#4-stufige Runge Kutta
# for i in range(0,n):
#     k1 = f(x[i], z[:,i])
#     k2 = f(x[i] + h/2, z[:,i] + h/2 * k1)
#     k3 = f(x[i] + h/2, z[:,i] + h/2 * k2)
#     k4 = f(x[i] + h, z[:,i] + h * k3)
#     x[i+1]=x[i]+h
#     z[:,i+1]=z[:,i]+h/6.*(k1 + 2*k2 + 2*k3 + k4)
    
#     print(x[i+1])
#     print(z[:,i+1])  

plt.plot(x,z[0,:],x,z[1,:],x,z[2,:],x,z[3,:]), plt.legend(["Lösung y(x)", "y'(x)","y''(x)","y'''(x)"])
# Out:
# 0.1
# [0.20002083 2.00081708 0.02436989 0.48127066]
# 0.2
# [0.40032391 2.00641817 0.0951032  0.92796539]
# 0.30000000000000004
# [0.60161385 2.02127345 0.20894182 1.34398379]
# 0.4
# [0.80502664 2.04954592 0.3629919  1.7327239 ]
# 0.5
# [1.01210065 2.09512544 0.55467725 2.09715183]
# 0.6
# [1.22475083 2.16165845 0.78169932 2.43986386]
# 0.7
# [1.44524567 2.25257395 1.04200303 2.76314191]
# 0.7999999999999999
# [1.6761867  2.3711064  1.33374785 3.06900312]
# 0.8999999999999999
# [1.92048998 2.5203159  1.6552836  3.35924428]
# 0.9999999999999999
# [2.18136966 2.70310621 2.00513044 3.63548158]
# ([<matplotlib.lines.Line2D at 0x1287854f0>,
#   <matplotlib.lines.Line2D at 0x1287854c0>,
#   <matplotlib.lines.Line2D at 0x128785310>,
#   <matplotlib.lines.Line2D at 0x128785520>],
#  <matplotlib.legend.Legend at 0x1286b34a0>)
