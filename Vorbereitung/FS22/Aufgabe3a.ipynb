# %%
import numpy as np
import matplotlib.pyplot as plt

G = 500
A = 25
K = 0.0025

def h(t):
    return G / (1 + ((G/A) -1) * np.exp(-K * G * t))

x = np.linspace(0, 10, 100)
plt.plot(x, h(x), '-')
plt.show()
