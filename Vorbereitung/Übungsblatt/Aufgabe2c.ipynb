# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 10000)

# x1, x2 = sp.symbols('x1 x2')
f1 = np.sqrt(1 - (x ** 2))
# f2 = -np.sqrt(1 - (x ** 2))
# f2 = (x2 - 500) ** 2 / 279 ** 2 - (x1 - 300) ** 2 / (500 ** 2 - 279 ** 2) * 1

# f1_lambdified = sp.lambdify((x1, x2), f1, modules='numpy')
# f2_lambdified = sp.lambdify((x1, x2), f2, modules='numpy')
plt.xlim(-3, 3)
plt.ylim(-4, 1.1) 
plt.plot(x, f1, color='r')
# plt.plot(x, f2, color='r')

# Plotten Sie die zweite Funktion
# plt.plot(x, f2_lambdified, color='b')

plt.show()
# Out:
# /var/folders/2s/dfn7s3d93xb1dj4229g62lww0000gn/T/ipykernel_20369/728425589.py:7: RuntimeWarning: invalid value encountered in sqrt
#   f1 = np.sqrt(1 - (x ** 2))
